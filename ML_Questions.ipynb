# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-26</div>

# %% [markdown]
# GenAI_&_LLM_Workflow_Questions
#
# 1. What’s the difference between fine-tuning an LLM and using prompt engineering? When would you choose one over the other?
# 2. How would you evaluate the performance of a GenAI application that generates product descriptions?
# 3. What is grounding in LLMs, and how does RAG help achieve it?
# 4. What are some common reasons for hallucinations in LLM responses even when using external context?
# 5. Why is token limit important when designing a multi-turn conversation system with an LLM?
# 6. How does a hybrid search (semantic + keyword) improve the performance of a RAG system?
# 7. How would you log, observe, and debug a GenAI pipeline in production?
# 8. What’s the purpose of using function calling or tool use in modern LLM frameworks like OpenAI or LangChain?
# 9. How would you design a modular GenAI pipeline where you can plug and play new LLMs or vector DBs easily?
# 10. What is context window management, and how does it affect system performance in long-running GenAI tasks?
#
# Scenario_Based_AI_System_Design_Questions
#
# 1. You’re asked to design a personal tutor bot for students preparing for competitive exams. What would be your high-level architecture?
# 2. You have a support ticketing system — how would you integrate LLM agents to classify, summarize, and route tickets automatically?
# 3. A company wants an internal knowledge bot that pulls data from Notion, Slack, PDFs, and SQL DBs. How would you approach the system design?
# 4. How would you design a GenAI-driven resume parser and job matcher that supports both structured and unstructured input?
# 5. You need a legal AI assistant that highlights risky clauses in contracts. What data pipeline and agent setup would you use?
# 6. In a multi-agent workflow, how would you ensure consistency in the tone and personality of responses across agents?
# 7. What architectural considerations are needed to support streaming (real-time) outputs from LLMs in a chat interface?
# 8. You built a document Q&A bot, but answers are sometimes irrelevant. How would you debug whether the issue is with retrieval, prompt, or the model?
# 9. You’re building a voice-enabled GenAI assistant — what changes would you make to a typical LLM pipeline to support speech?
# 10. If you had to deploy a GenAI solution in an enterprise environment with strict data privacy rules, how would your architecture change?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-25</div>

# %% [markdown]
# GenAI_&_LLM-Based_System_Design_Questions
#
# 1. How would you design a GenAI system that summarizes emails and routes them to the right department?
# 2. What are the key components required to build a retrieval-augmented generation (RAG) pipeline?
# 3. In a multi-agent AI system, how do agents communicate and collaborate to solve a task?
# 4. What is prompt chaining, and how does it impact LLM-based workflows?
# 5. How would you handle hallucination problems in a customer-facing chatbot built on top of an LLM?
# 6. What’s the role of vector databases in LLM applications, and how are they different from traditional SQL DBs?
# 7. How would you design a GenAI-powered interview bot that adapts its questions based on candidate answers?
# 8. How can you connect structured (SQL) and unstructured (PDF, emails) data sources in one GenAI pipeline?
# 9. Why is system design important even for data scientists working with LLMs?
# 10. How would you scale a GenAI chatbot that handles thousands of user requests per hour in real-time?
#
# Scenario_Based_AI_Agent_Questions
#
# 1. You have a query like “What are my pending orders and what do the contract terms say?” — how would a multi-agent system handle it?
# 2. A customer asks an ambiguous question. How would you design an agent to decide whether to ask a clarifying question or respond?
# 3. You want to automate RFP (Request for Proposal) responses. How would an LLM agent framework help?
# 4. How would you design a planner-agent setup where one agent creates a task list and others execute it?
# 5. You built a sales assistant using agents. A bug causes repeated queries to SQL DB. What would you check in the design?
# 6. You want the LLM to call APIs dynamically (e.g., for real-time weather). What architectural design allows this?
# 7. How would you design a fallback mechanism when the LLM response confidence is low or data is missing?
# 8. You're asked to add GenAI capabilities to an existing analytics dashboard. How would you integrate an LLM safely?
# 9. Your LLM app is giving different answers for the same question across sessions. What architectural or prompt-level reasons could cause this?
# 10. How would you secure sensitive data when building GenAI agents that access internal documents?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-24</div>

# %% [markdown]
# Machine_Learning_Questions
#
# 1. If your model has 100% accuracy on the training set, what should be your immediate suspicion?
# 2. Why does scaling matter more in algorithms like KNN and SVM compared to decision trees?
# 3. How can you decide whether your model is underfitting or overfitting just by looking at performance metrics?
# 4. In what situation can adding more data hurt model performance?
# 5. What’s the difference between bagging and boosting — not just technically but in terms of error handling?
# 6. How does dropout help in preventing overfitting in deep learning models?
# 7. Why is model interpretability crucial in domains like healthcare and finance?
# 8. Why does regularization help improve generalization?
# 9. When is it better to use a shallow model over a deep one?
# 10. What are some real-world examples where linear models outperform deep learning models?
#
# Natural_Language_Processing_(NLP)_Questions
#
# 1. What is the difference between context-free and context-aware embeddings?
# 2. How does self-attention allow transformers to scale better than RNNs for long sequences?
# 3. Why is sentence segmentation more challenging in multilingual or informal texts?
# 4. What are hallucinations in large language models, and why do they occur?
# 5. How can prompt engineering improve NLP outputs without changing the model?
# 6. How does zero-shot learning work in NLP models?
#
# Statistics_Probability_Questions
#
# 1. Why can a statistically significant result still be practically insignificant?
# 2. What assumptions must be satisfied for linear regression to work well?
# 3. What’s the role of degrees of freedom in statistical tests?
# 4. How can outliers affect the mean and standard deviation?
# 5. What’s the difference between descriptive and inferential statistics, and where do we use each?
#
# Classification_Questions
#
# 1. In a multi-class classification problem, why is micro vs. macro averaging important?
# 2. How does SMOTE work, and what are its limitations?
# 3. What causes a model to have high recall but low precision?
# 4. Why might your model predict only one class in an imbalanced dataset?
# 5. How does label encoding differ from one-hot encoding in the context of classification?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-23</div>

# %% [markdown]
# Machine_Learning_Questions_(Tricky but Basic)
#
# 1. Can dropping features improve model performance? How do you decide?
# 2. Why is data imbalance not always a problem?
# 3. What’s the difference between randomness and noise in training data?
# 4. Why might a model’s performance decrease after hyperparameter tuning?
# 5. How does imputation of missing values introduce bias?
# 6. When can scaling after train-test split lead to data leakage?
# 7. What’s the risk of using polynomial features blindly in linear models?
# 8. Can high F1-score be misleading? When?
# 9. Why is model interpretability important in regulated industries?
# 10. Why should you be cautious about reusing test data for model selection?
#
# Natural_Language_Processing_(NLP)_Questions
#
# 1. How does domain-specific vocabulary affect pre-trained NLP models?
# 2. What is the risk of using sentiment lexicons across different domains (e.g., finance vs. movies)?
# 3. Why does length normalization matter in text similarity tasks?
# 4. What’s the issue with blindly using TF-IDF in very short texts?
# 5. Why might a generative model repeat phrases in its outputs?
# 6. How can POS tagging errors cascade into bigger NLP mistakes?
#
# Statistics_Probability_Questions
#
# 1. Why is standard deviation not always the best measure of spread?
# 2. What’s the subtle trap in interpreting p-values near 0.05?
# 3. Can two distributions have the same mean and variance but still be very different?
# 4. Why is random sampling not truly random in code?
# 5. What is the danger in aggregating data without stratification?
#
# Classification_Questions
#
# 1. How does label noise affect classifier training?
# 2. Why can a high AUC still mean a poor model for threshold-based decisions?
# 3. When is log-loss a better metric than accuracy?
# 4. How can overly confident predictions hurt in real-world applications?
# 5. Why is multiclass classification harder than it seems with one-vs-rest?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-22</div>

# %% [markdown]
# Part – 22
#
# hashtag#Machine_Learning_Questions_(Tricky but Basic)
#
# 1. Why might a model perform worse on real-world data even after achieving great cross-validation results?
# 2. How does feature scaling impact gradient descent performance?
# 3. Why can adding polynomial features lead to overfitting in linear models?
# 4. How is entropy used in decision trees, and what does it really represent?
# 5. Why doesn’t increasing model complexity always improve accuracy?
# 6. What’s the intuition behind k-nearest neighbors being a “lazy learner”?
# 7. How do learning rate and batch size interact in training a deep learning model?
# 8. Why are tree-based models invariant to feature scaling, but linear models are not?
# 9. In boosting algorithms, how does the model correct previous errors?
# 10. Why is interpretability often a trade-off with model accuracy?
#
# hashtag#Natural_Language_Processing_(NLP)_Questions
#
# 1. Why is tokenization a non-trivial step in NLP pipelines?
# 2. How do attention mechanisms differ from traditional RNNs in handling long sequences?
# 3. Why can padding and truncation impact model performance in NLP?
# 4. What are stopwords, and when should you avoid removing them?
# 5. Why are word embeddings better than one-hot encoding?
# 6. How do named entity recognition systems deal with ambiguous entities?
#
# hashtag#Statistics_Probability_Questions
#
# 1. What’s the law of large numbers, and how does it differ from the central limit theorem?
# 2. Why can two datasets have the same mean but different standard deviations?
# 3. How does correlation differ from causation, and why is this distinction critical?
# 4. Why is standard error smaller than standard deviation in most cases?
# 5. What are p-values often misunderstood to represent?
#
# hashtag#Classification_Questions
#
# 1. Why can accuracy be misleading in imbalanced datasets?
# 2. What is precision-recall trade-off, and how does it affect model choice?
# 3. How does threshold tuning impact classification metrics?
# 4. Why might you prefer F1-score over accuracy in medical diagnoses?
# 5. What does it mean if a classifier has high precision but low recall?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-21</div>

# %% [markdown]
# Part – 21
#
# hashtag#Excel_&_Spreadsheet_Questions
#
# 1. What happens if you drag a formula with relative references versus absolute references?
# 2. Can a pivot table work without a numeric value field?
# 3. How do you find the 5 most frequent values in a column without using VBA?
# 4. What’s the difference between COUNT, COUNTA, and COUNTIF?
# 5. Can you filter data in Excel without removing any rows?
#
# hashtag#SQL_&_Database_Questions
#
# 1. What will happen if you use GROUP BY without an aggregate function?
# 2. Can you use ORDER BY in a subquery?
# 3. Why does NULL = NULL return false in SQL?
# 4. What is the difference between DELETE and TRUNCATE, and which is faster?
# 5. Can a table have multiple PRIMARY KEYs?
#
# hashtag#Data_Interpretation_&_Logic
#
# 1. If a bar chart shows increasing sales, does it always mean increased profit? Why or why not?
# 2. You found a spike in data — how do you decide whether it's an error or a business event?
# 3. Can correlation be negative? What does it indicate in business terms?
# 4. A report shows a 200% growth from 1 to 3. Is that valid?
# 5. How do you handle a situation where data from two sources don’t match?
#
# hashtag#Business_&_Analytics Thinking
#
# 1. A manager says sales are low – what 3 quick checks would you do first?
# 2. Why is “average” sometimes a misleading metric in business dashboards?
# 3. How would you explain a complex chart to a non-technical stakeholder?
# 4. If a KPI is improving but business is not, what could be wrong?
# 5. Can good data analysis lead to bad business decisions

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-20</div>

# %% [markdown]
# Part – 20
#
# hashtag#Machine_Learning_Questions_(Tricky but Basic)
#
# 1. Why can a high training accuracy be misleading when evaluating a model's performance?
# 2. What’s the intuition behind the bias-variance trade-off?
# 3. Why is random initialization crucial in training neural networks?
# 4. In ensemble methods like random forests, why is averaging predictions better than taking a majority vote?
# 5. How does L1 regularization differ from L2, and when would you use each?
# 6. What’s the purpose of using an activation function in neural networks?
# 7. How does increasing the number of estimators in a random forest impact model performance?
# 8. Why can using too many features lead to worse model performance, and how can you detect it?
# 9. How does early stopping work in deep learning, and why is it useful?
# 10. What is data leakage, and how can it affect your machine learning model?
#
# hashtag#Natural_Language_Processing_(NLP)_Questions
#
# 1. Why is stemming sometimes less accurate than lemmatization?
# 2. How does positional encoding help transformer-based models understand word order?
# 3. What are the challenges in handling code-mixed languages (e.g., Hinglish) in NLP?
# 4. Why are subword tokenization techniques (like Byte-Pair Encoding) preferred in large language models?
# 5. What is the vanishing gradient problem, and how do RNNs suffer from it?
# 6. Why is fine-tuning pre-trained models more effective than training from scratch in NLP?
#
# hashtag#Statistics_Probability_Questions
#
# 1. What is the central limit theorem, and why is it important in data science?
# 2. When would you prefer a non-parametric test over a parametric one?
# 3. Why does increasing sample size reduce sampling error but not necessarily eliminate bias?
# 4. How do confidence intervals help interpret statistical results?
# 5. What is the difference between Type I and Type II errors, and how do they affect model decisions?
#
# hashtag#Classification_Questions
#
# 1. What is a confusion matrix, and how does it help evaluate model performance?
# 2. Why is ROC-AUC a better evaluation metric in imbalanced classification problems?
# 3. How can class imbalance be addressed during training?
# 4. What’s the role of regularization in logistic regression?
# 5. How does a decision boundary change when using different kernels in SVM?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-19</div>

# %% [markdown]
# #Tricky Data Science Interview Questions Based on Real World Scenarios – Part 19
# hashtag#FeatureEngineering hashtag#TimeSeries hashtag#MLDeployment
#
# hashtag#Feature Engineering Questions
#
# 1. Your model performs well during training but poorly on test data. Could feature leakage be the reason?
#  💡 *Hint:* If future information accidentally leaks into training features, it leads to over-optimistic performance. Audit features carefully.
#
# 2. You suspect multicollinearity in your regression model. How would you detect and resolve it?
#  💡 *Hint:* Use Variance Inflation Factor (VIF) to identify highly correlated predictors and consider dimensionality reduction like PCA.
#
# 3. You're working with categorical variables that have high cardinality. What's your encoding strategy?
#  💡 *Hint:* Use target encoding, frequency encoding, or embeddings instead of one-hot to avoid high dimensionality.
#
# hashtag#Time Series Questions
#
# 4. Your time series model performs poorly despite good cross-validation scores. What’s likely wrong?
#  💡 *Hint:* You might be using random CV splits — switch to time-based cross-validation to preserve temporal order.
#
# 5. Your ARIMA model’s residuals are autocorrelated. What does this suggest?
#  💡 *Hint:* The model isn’t capturing all temporal structure — try adding seasonal terms or moving to SARIMA/Prophet.
#
# 6. You’re forecasting demand, but COVID-19 caused a huge spike in 2020. How do you handle such anomalies?
#  💡 *Hint:* Treat them as outliers — either remove, smooth, or model them separately as shocks or interventions.
#
# hashtag#ML Deployment / Production Questions
#
# 7. Your deployed model suddenly starts making worse predictions. What’s the first thing to check?
#  💡 *Hint:* Check for data drift or concept drift — retrain the model or add monitoring pipelines.
#
# 8. Your model is slow during inference in production. What could be optimized?
#  💡 *Hint:* Quantization, model pruning, using a faster algorithm, or switching to a lightweight framework (ONNX, TensorRT).
#
# 9. You notice discrepancies between training and production predictions. What’s going wrong?
#  💡 *Hint:* Check for training-serving skew — inconsistent preprocessing, version mismatches, or feature changes.
#
# hashtag#Bonus: General Tricky
#
# 10. You build a perfect model, but business stakeholders are still unsatisfied. Why?
#  💡 *Hint:* Model performance ≠ business impact — focus on interpretability, trust, and aligning with KPIs.
#
# 11. A colleague says adding more features always improves model performance. Agree?
#  💡 *Hint:* Not necessarily more features can lead to overfitting, multicollinearity, or noise.
#
# 12. You’re asked to choose between a slightly less accurate but interpretable model vs. a black-box model. What factors guide your choice?
#  💡 *Hint:* Consider domain requirements, risk, regulatory needs, and explainability trade-offs.

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-18</div>

# %% [markdown]
# Tricky Data Science Interview Questions Based on Real World Scenarios – Part 18
#
# hashtag#Machine_Learning_Questions
#
# 1. You’re working with a small dataset but need high accuracy. Would you choose a deep learning model or a traditional ML model? Why?
# 💡 Hint: Deep learning tends to overfit on small datasets. Traditional models like decision trees, logistic regression, or SVMs are more data-efficient.
#
# 2. Your model takes too long to train, even though the dataset is small. What would you check first?
# 💡 Hint: High-dimensional data, redundant features, suboptimal algorithm choice, lack of feature selection.
#
# 3. Your classification model performs well overall but fails on a **minority class. How do you fix this?
# 💡 Hint: Apply class imbalance techniques like SMOTE, weighted loss functions, or threshold tuning.
#
# hashtag#NLP_Questions
#
# 4. Your chatbot responds with generic answers instead of meaningful replies. What could be wrong?
# 💡 Hint: Poor training data, lack of context handling, inadequate fine-tuning.
#
# 5. Your text classifier struggles with OOV (Out-of-Vocabulary) words. What's your approach?
# 💡 Hint: Use subword tokenization like Byte Pair Encoding (BPE) or WordPiece, and leverage pre-trained embeddings.
#
# 6. Your NER model misses multi-word entities (e.g., “New York City”). What might be the issue?
# 💡 Hint: Incorrect tokenization, lack of contextual understanding, or need for better N-gram/contextual models.
#
# hashtag#Statistics_Questions
#
# 7. Two variables have a 90% correlation. Does one cause the other? How can you verify?
# 💡 Hint: Correlation ≠ Causation. Run controlled experiments, use causal inference methods, or check for confounders.
#
# 8. Your regression model’s residuals show a clear pattern. What does this indicate?
# 💡 Hint: Model assumptions are violated — possible non-linearity, heteroscedasticity, or missing variables.
#
# 9. Your dataset has many missing values. How can you handle them without losing valuable insights?
# 💡 Hint: Use imputation (mean/median/KNN), analyze missing patterns, or consider model-based imputation.
#
#  hashtag#Classification_Questions
#
# 10. Your model shows 98% accuracy, but users report poor performance in key scenarios. What’s likely wrong?
# 💡 Hint: Accuracy is misleading with imbalanced data — focus on precision, recall, and F1-score.
#
# 11. Your fraud detection model flags too many false positives. How would you handle this?
# 💡 Hint: Adjust classification threshold, evaluate precision-recall trade-offs, or retrain with cost-sensitive learning.
#
# 12. Your multi-class classifier confuses similar classes. How do you fix it?
# 💡 Hint: Use better feature engineering, hierarchical classification, or fine-tuned contextual embeddings.
#
# 13. Your decision tree gives inconsistent predictions on the same input. Why?
# 💡 Hint: No fixed random seed, instability in tree splits — consider bagging or ensemble methods like Random Forest.

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-17</div>

# %% [markdown]
# **Top Interview Questions for Data Science Freshers:
# Commonly Overlooked but Important Concepts – Part 17**
#
# 🔍 hashtag#Data_Understanding_Preprocessing
#
# 1. Why is it important to understand the data distribution before modeling?
# 2. How can missing values introduce bias into your model?
# 3. What is the difference between normalization and standardization, and when do you use each?
# 4. Why should you be cautious with duplicate records in your dataset?
# 5. What is the impact of high cardinality categorical variables on models?
#
#  📉 hashtag#Evaluation_Model_Selection
#
# 1. What is cross-validation leakage and how can you prevent it?
# 2. Why is it risky to tune hyperparameters on the test set?
# 3. How do you choose the right evaluation metric for your business problem?
# 4. What’s the difference between validation score and generalization performance?
# 5. Why might your model perform poorly in production even though it performed well in training/testing?
#
# 📦 hashtag#Feature_Engineering
#
# 1. Why is domain knowledge important in feature engineering?
# 2. How can you use interaction terms to improve model performance?
# 3. What are dummy variable traps, and how do you avoid them?
# 4. Why should you be cautious when using date/time features directly?
# 5. How do you deal with multiscale features in the same dataset?
#
# ⚙️ hashtag#Practical_ML_Workflow_Concepts
#
# 1. What is a data pipeline, and why is it important in production systems?
# 2. How do you handle data drift or concept drift over time?
# 3. What are the trade-offs between real-time and batch inference?
# 4. Why is version control important in datasets and models?
# 5. What is the importance of reproducibility in machine learning?
#
# 👁️‍🗨️ hashtag#Soft_Skills_Collaboration
#
# 1. How would you explain your model to a non-technical stakeholder?
# 2. Why is documenting your analysis and assumptions crucial?
# 3. What steps would you take to debug a model giving weird predictions?
# 4. How do you handle disagreement with a domain expert about a modeling decision?
# 5. Why is iteration important in data science projects?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-16</div>

# %% [markdown]
# **Top Interview Questions for Data Science Freshers: ML, NLP, Classification & GenAI** Part- 16
#
# 🧠 Machine Learning: “Why” & Tricky Conceptual Questions
# 1. Why can high accuracy in training sometimes mean poor generalization in real-world scenarios?
# 2. Why does K-Means fail on non-spherical clusters, and how can this be addressed?
# 3. Why might gradient descent converge slowly even with a well-chosen learning rate?
# 4. Why is feature engineering often more impactful than model selection?
# 5. Why can ensemble models (like stacking) outperform a single deep model, despite deep models being more complex?
# 6. Why is interpretability considered a key advantage in linear models over neural networks?
# 7. Why might removing multicollinear features still hurt model performance sometimes?
# 8. Why is it recommended to use stratified sampling in classification tasks?
# 9. Why can dimensionality reduction (e.g., PCA) sometimes worsen model performance?
# 10. Why doesn’t increasing model depth always improve neural network performance?
#
# 💬 Natural Language Processing (NLP): “Why” Questions
# 1. Why do transformer models rely on positional encoding, and what happens without it?
# 2. Why is cosine similarity preferred over Euclidean distance in text vector comparisons?
# 3. Why is semantic understanding hard with bag-of-words or TF-IDF?
# 4. Why do language models struggle with sarcasm or irony?
# 5. Why can using subword tokenization improve performance in low-resource languages?
# 6. Why is zero-shot learning difficult in traditional NLP pipelines but more feasible with models like GPT?
# 7. Why are pre-trained embeddings not always transferable across domains (e.g., legal vs. medical)?
# 8. Why does sequence length impact transformer memory usage and model speed?
# 9. Why is co-reference resolution critical in conversational AI?
# 10. Why do multilingual NLP models often perform worse than monolingual models on language-specific tasks?
#
# 🧪Classification: “Why” & Edge Cases
#
# 1. Why might F1-score be misleading in multi-class imbalanced settings?
# 2. Why can adding more classes reduce classifier confidence across all predictions?
# 3. Why does class overlap reduce maximum achievable accuracy—even with perfect modeling?
# 4. Why might ROC-AUC give a false sense of performance in skewed datasets?
# 5. Why is label noise more harmful for some algorithms than others?
# 6. Why doesn’t over-sampling always improve classifier performance?
# 7. Why should calibration be checked even when the classifier has high accuracy?
# 8. Why do some models predict the majority class even after training on a balanced set?
# 9. Why is sigmoid activation not suitable for multi-class problems?
# 10. Why do decision boundaries for logistic regression stay linear, and how can we overcome this?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-15</div>

# %% [markdown]
# ⚜️ Top Interview Questions for Data Science Freshers: ML, NLP, and Statistics ⚜️ - Part 15
#
# 💡 Machine Learning – Tricky & Thought-Provoking
#
# 1. How would you train a model when your dataset has 90% duplicates? Would removing duplicates always help?
# 2. Can a model with lower training accuracy outperform a model with higher training accuracy on test data? Why?
# 3. How would you explain variance vs. bias trade-off **without using equations**?
# 4. Your model performs very well on cross-validation but poorly in production. What are some possible root causes?
# 5. How would you detect **data leakage** in a model pipeline? Give real-world examples.
#
# 💡 Natural Language Processing – Edge Cases & Ambiguities
#
# 1. Your sentiment model classifies “I just *love* when my phone crashes” as positive. What’s going wrong, and how do you fix it?
# 2. How would you design a language model that can differentiate between “bank” (finance) and “bank” (river)?
# 3. What challenges do multilingual NLP models face, especially in low-resource languages?
# 4. How can named entity recognition (NER) fail when applied to social media text?
# 5. How would you handle sarcasm, code-mixing, and emoji use in user-generated content?
#
# 💡 Statistics – Conceptual Depth
#
# 1. Can two distributions have the same mean and variance but be completely different? Explain with an example.
# 2. Why might a statistically significant result still not be practically meaningful?
# 3. What is Simpson’s Paradox, and how might it mislead conclusions in an A/B test?
# 4. You conduct a test and get a p-value of 0.049. Would you treat this differently from a p-value of 0.051? Why or why not?
# 5. What does it mean when your model performs well, but the confidence intervals for your predictions are wide?
#
# 💡 Real-World/Applied – Tough Decision Making
#
# 1. You only have access to aggregated data (not raw data) due to privacy concerns. How would you still build a useful model?
# 2. Your classification model is misclassifying minority class instances despite using SMOTE. What next?
# 3. You’re given a legacy model with no documentation but asked to improve it. How do you reverse engineer its logic?
# 4. Your manager insists on using accuracy as the primary metric. How do you convince them otherwise in an imbalanced classification task?
# 5. You have a high-performing model, but the business team finds the predictions untrustworthy. What would you do?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-14</div>

# %% [markdown]
# ⚜️ Top Interview Questions for Data Science Freshers: ML, NLP, and Statistics ⚜️ - Part 14
#
# 💡Machine Learning Questions
# 1. Why does adding noise to your data sometimes improve the robustness of a model?
# 2. Why might ensemble models like Random Forest perform poorly on a dataset with many categorical variables?
# 3. Why is the learning rate in gradient descent a critical hyperparameter, and how do you decide its value?
# 4. How would you explain the difference between bagging and boosting to a non-technical stakeholder?
# 5. Why does dropout improve generalization in neural networks, and how does it work?
#
# 💡Natural Language Processing Questions
# 1. Why might language models struggle with sarcasm or idioms, and how could you improve their performance in such cases?
# 2. Why are recurrent neural networks (RNNs) less efficient for handling long sequences compared to transformer models?
# 3. Why is the BLEU score commonly used for machine translation, and what are its limitations?
# 4. Why might stopword removal harm the performance of a topic modeling algorithm like LDA?
# 5. How would you approach cleaning noisy text data from multiple languages in a dataset?
#
# 💡 Statistics Questions
# 1. Why is it important to check for outliers before running statistical tests, and how might they impact results?
# 2. If two variables have a correlation coefficient of 0, why might they still have a relationship?
# 3. Why do Bayesian methods often require priors, and how do you select a good prior?
# 4. In regression, why might a high R-squared value still not indicate a good model?
# 5. Why is the assumption of independence important in many statistical tests, and how would you test for it?
#
# 💡 Scenario-Based/Real-World Questions
# 1. Your model’s predictions are consistently biased for one specific class. How would you debug and resolve this issue?
# 2. Why might scaling features improve performance in clustering algorithms like K-Means but not in tree-based models?
# 3. You’re asked to build a model for a rare disease prediction. Why might precision be more critical than recall in this case?
# 4. If a dataset has missing values in only one feature, why might imputing with the mean not always be a good idea?
# 5. Your team wants to deploy a sentiment analysis model, but the output is inconsistent. How would you identify and fix the issue?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-13</div>

# %% [markdown]
# **Top Interview Questions for Data Science Freshers: ML, NLP, and Statistics** Part-13
#
# Some of these are straightforward, but others are tricky and designed to test your understanding.
#
# **Machine Learning Questions**
# 1. Why is mean squared error (MSE) preferred over mean absolute error (MAE) in some cases, and vice versa?
# 2. If a model has 95% accuracy, does it mean it’s a good model? Why or why not?
# 3. Why do deep learning models perform better with large amounts of data but struggle with small datasets?
# 4. What happens if you remove all hidden layers from a neural network?
# 5. Can a model with high bias ever outperform a model with low bias?
#
# **Natural Language Processing (NLP) Questions**
# 1. Why might removing stopwords sometimes hurt model performance instead of improving it?
# 2. If two sentences have the same words but in a different order, will a bag-of-words model treat them as the same? Why or why not?
# 3. Why can’t we just use TF-IDF for deep learning-based NLP models?
# 4. How does a chatbot understand the intent behind a sentence?
# 5. Why is it difficult for AI models to understand sarcasm?
#
# **Statistics & Probability Questions**
# 1. If the probability of rain tomorrow is 80%, does that mean it will rain for 80% of the day? Why or why not?
# 2. Why can a small dataset sometimes give misleading statistical results?
# 3. If you flip a fair coin 10 times and get 7 heads, does that mean the coin is biased? Why or why not?
# 4. If a dataset has a mean of 50 and a median of 30, what does that suggest about its distribution?
# 5. Why is it incorrect to say that a p-value of 0.03 means there is a 97% probability the null hypothesis is false?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-12</div>

# %% [markdown]
# **Top Interview Questions for Data Science Freshers: ML, NLP, and Statistics** Part- 12
#
# hashtag#Machine_Learning_Questions_(Tricky but Basic)
# 1. Why do we prefer using cross-validation instead of a simple train-test split?
# 2. How does increasing the number of hidden layers in a neural network impact model performance?
# 3. Why is feature scaling important for algorithms like KNN and SVM but not for decision trees?
# 4. What is the difference between underfitting and overfitting? Can a model be both at the same time?
# 5. Why do we sometimes prefer simpler models (like logistic regression) over complex deep learning models?
# 6. How does the learning rate impact gradient descent, and what happens if it is too high or too low?
# 7. Why do deep learning models typically require large datasets to perform well?
# 8. What happens if you initialize all weights to zero in a neural network?
# 9. Why is dropout used in deep learning, and how does it help prevent overfitting?
# 10. How does batch normalization improve training stability in deep neural networks?
#
# hashtag#Natural_Language_Processing_(NLP)_Questions
# 1. If a chatbot keeps misinterpreting user queries, what are some potential causes?
# 2. How does an attention mechanism help in NLP models like transformers?
# 3. Why is one-hot encoding not a good choice for representing words in large vocabularies?
# 4. How does BERT differ from traditional word embedding techniques like Word2Vec?
# 5. Why is named entity recognition (NER) difficult in multilingual models?
# 6. Why might a TF-IDF vectorization approach fail in understanding sentence meaning?
#
# hashtag#Statistics_Probability_Questions
# 1. Why does correlation not imply causation? Give a real-world example.
# 2. If a dataset has extreme outliers, why might the median be a better measure of central tendency than the mean?
# 3. What is Simpson’s paradox, and how can it lead to incorrect conclusions?
# 4. Why is it important to check for multicollinearity in regression models?
# 5. What is heteroscedasticity, and why is it a problem in regression models?
#
# hashtag#Classification_Questions
# 1. Why is accuracy not always a good metric for evaluating classification models?
# 2. What is the difference between precision and recall, and when would you prioritize one over the other?
# 3. Why does increasing the number of training samples not always improve classification performance?
# 4. Why is softmax used instead of sigmoid in multi-class classification?
# 5. What happens if a logistic regression model is trained on highly correlated features?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-11</div>

# %% [markdown]
# ⚜️ Top Interview Questions for Data Science Freshers: ML, NLP, Statistics & Time Series ⚜️ - Part 11
#
# ⚜️Machine Learning Questions⚜️
# 1. Why might a simpler model like Ridge Regression outperform a more complex one like Gradient Boosting on certain datasets?
# 2. Why is the choice of distance metric critical in clustering algorithms, and how would you decide which one to use?
# 3. How would you explain the concept of cross-entropy loss to someone without a technical background?
# 4. Why do neural networks benefit from non-linear activation functions?
# 5. Why might feature interactions in linear models require manual engineering, but not in tree-based models?
#
# ⚜️Natural Language Processing Questions⚜️
# 1. How would you approach a text classification problem with a highly imbalanced dataset?
# 2. How does subword tokenization handle out-of-vocabulary (OOV) words better than traditional tokenization?
# 3. Why might text data with heavy sarcasm or negation pose challenges for sentiment analysis models?
# 4. Why does pre-training on large corpora make transformers so effective for NLP tasks?
#
# ⚜️Statistics Questions⚜️
# 1. Why is the standard deviation more useful than the range in describing the variability of a dataset?
# 2. Why might an unbiased estimator not always be preferred over a biased one?
# 3. How would you explain the importance of sampling distribution in inferential statistics?
# 4. Why might a statistically significant result not always be practically significant?
#
# ⚜️Time Series Questions⚜️
# 1. Why is stationarity important in time series forecasting, and how would you test for it?
# 2. How does differencing help in making a time series stationary, and why is it sometimes necessary?
# 3. Why might ARIMA models struggle with datasets that exhibit sudden structural changes or outliers?
# 4. How would you handle missing timestamps in a time-series dataset, and why might interpolation not always be the best choice?
# 5. Why is seasonality challenging in time-series forecasting, and how would you model it?
#
# ⚜️Scenario-Based/Real-World Questions⚜️
# 1. Your time-series model underperforms because the data has irregular intervals. How would you address this?
# 2. You’re building an image classification model, but the training data contains mislabeled samples. How would you identify and handle them?
# 3. Your NLP model fails to detect sarcasm in product reviews. How would you approach improving it?
# 4. A client asks you to predict energy demand for a smart grid. How would you handle exogenous variables like weather and holidays?
# 5. Your statistical analysis shows a significant relationship between variables, but the domain expert says it’s not meaningful. How would you reconcile this?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-10</div>

# %% [markdown]
# **Top Interview Questions for Data Science Freshers: ML, NLP, and Statistics** - Part 10
#
#  **Machine Learning Questions**
# 1. Why might adding more features to a dataset degrade model performance? How would you identify and remove irrelevant features?
# 2. Why is gradient descent not guaranteed to find the global minimum in non-convex loss functions?
# 3. Why might you prefer a simpler model like Logistic Regression over a complex one like a Neural Network in some cases?
# 4. If your model's AUC score is high but precision is low, why might this happen, and how would you address it?
# 5. Why do tree-based algorithms like XGBoost handle missing values better than most other models?
#
#  **Natural Language Processing Questions**
# 1. Why is subword tokenization (e.g., Byte-Pair Encoding) useful in handling rare words in NLP tasks?
# 2. Why might overfitting be a bigger issue in NLP tasks compared to tabular data?
# 3. If you’re training an NLP model, why might smaller batch sizes lead to better generalization for text data?
# 4. Why do transformer models like GPT require positional encoding, and how does it work?
# 5. Why might text summarization models struggle with long documents, and how would you overcome this?
#
# **Statistics Questions**
# 1. Why is it important to check the distribution of residuals in regression analysis?
# 2. If two datasets have the same mean and variance, why might they still have very different distributions?
# 3. Why is it crucial to consider sample size when interpreting confidence intervals?
# 4. In A/B testing, why might a test that runs for too long lead to misleading results?
# 5. Why might you use bootstrapping instead of traditional hypothesis testing for small datasets?
#
# **Scenario-Based/Real-World Questions**
# 1. Your model is biased against certain demographics. Why might this happen, and how would you mitigate it?
# 2. You’re tasked with building a recommendation system for a new e-commerce site with no historical data. How would you approach this?
# 3. If your dataset contains a high percentage of duplicate entries, why might this affect your model’s performance?
# 4. Why might deploying a model trained on cloud GPUs fail to perform well on edge devices?
# 5. You’re working with a time-series dataset where sudden spikes occur. Why might traditional smoothing techniques fail, and what alternatives would you use?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-9</div>

# %% [markdown]
# #Top Interview Questions for Data Science Freshers: Model Evaluation, Feature Engineering, and Ensemble Learning Part - 9
#
# hashtag#Model_Evaluation_Optimization_Questions_(Tricky but Basic)
# 1. What is cross-entropy loss, and when is it used in classification tasks?
# 2. What does the ROC curve represent, and how should AUC be interpreted?
# 3. Why is early stopping helpful during model training?
# 4. How do learning curves help diagnose underfitting or overfitting?
# 5. What is the bias-variance tradeoff, and how do you handle it?
# 6. Why is hyperparameter tuning critical, and what are common techniques?
# 7. What is k-fold cross-validation, and why is it better than holdout validation?
# 8. Why do models sometimes perform worse after tuning or regularization?
# 9. What is the difference between L1 and L2 regularization?
# 10. How can a confusion matrix provide more insights than accuracy alone?
#
# hashtag#Feature_Engineering_Preprocessing_Questions
# 1. Why is handling missing data important, and what are common strategies?
# 2. What happens if categorical variables are not encoded properly?
# 3. How does feature scaling influence distance-based models?
# 4. What are interaction features, and how do they improve model performance?
# 5. Why should we be cautious of data leakage during preprocessing?
# 6. What are derived features, and how can they give your model an edge?
# 7. How do you detect multicollinearity, and why should it be addressed?
# 8. When is dimensionality reduction useful, and what are common techniques?
# 9. What is target encoding, and what risks does it bring?
# 10. How do outliers affect machine learning models?
#
# hashtag#Ensemble_Learning_Questions
# 1. What is the key difference between bagging and boosting?
# 2. How does Random Forest reduce overfitting compared to a single decision tree?
# 3. Why is XGBoost often preferred for structured/tabular datasets?
# 4. What is stacking in ensemble learning, and how does it work?
# 5. Can ensemble methods overfit? How do you prevent it?
# 6. What are the advantages and drawbacks of using ensemble models?
# 7. When would a simple model outperform an ensemble?
# 8. How does voting work in classification ensembles?
# 9. What are feature importances in ensemble models, and how are they useful?
# 10. Why might ensemble models be harder to interpret?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-9</div>

# %% [markdown]
# #Tricky_Data_Science_Interview_Questions_Based_on_Real_World_Scenarios Part -9
#
# Here are some real-world scenario-based questions that test your ability to apply data science concepts rather than just recall definitions.
#
# hashtag#Machine_Learning_Questions
#
# 1. You are working with a small dataset but still need high accuracy. Would you choose a deep learning model or a traditional ML model? Why?
# hashtag#Hint: Overfitting risk in deep learning, need for more data-efficient models like decision trees or logistic regression.
#
# 2. Your model is taking too long to train, even though the dataset isn’t very large. What would you check first?
# hashtag#Hint: High-dimensional features, redundant data, inefficient algorithm choice, need for feature selection.
#
# 3. Your classification model is working well for most classes, but it performs poorly on a minority class. How do you fix this?
# hashtag#Hint: Class imbalance techniques (SMOTE, weighted loss function, threshold tuning).
#
# hashtag#NLP_Questions
# 4. Your chatbot is responding with generic answers instead of meaningful replies. What could be the issue?
#  hashtag#Hint: Poor training data, lack of context awareness.
#
# 5. Your text classification model struggles with out-of-vocabulary (OOV) words. What’s your approach?
# hashtag#Hint: Subword tokenization (Byte Pair Encoding, WordPiece), using pre-trained embeddings.
#
# 6. Your named entity recognition (NER) model is missing entities that contain multiple words (e.g., "New York City"). What might be the problem?
# hashtag#Hint: Incorrect tokenization, need for better N-gram modeling, using contextual embeddings.
#
# hashtag#Statistics_Questions
#
# 7. You see two variables with 90% correlation. Does this mean one causes the other? How do you verify?
# hashtag#Hint: Causation ≠ Correlation, use experiments, look for confounding variables.
#
# 8. You built a regression model, but the residuals show a clear pattern. What does this mean?
# hashtag#Hint: The model violates assumptions (non-linearity, heteroscedasticity).
#
# 9. Your dataset contains many missing values. How would you handle them without losing important patterns?
# hashtag#Hint: Imputation techniques (mean, median, KNN-based imputation), analyzing missing data patterns.
#
# hashtag#Classification_Questions
# 10. Your model has 98% accuracy, but users complain that it performs poorly in critical cases. What’s the issue?
# hashtag#Hint: Imbalanced data, use precision-recall, F1-score instead of accuracy.
#
# 11. You deployed a fraud detection model, but it’s catching too many false positives. How would you adjust it?
# hashtag#Hint: Adjust classification threshold, optimize precision-recall trade-off.
#
# 12. Your multi-class classification model confuses similar-looking classes. How do you fix it?
# hashtag#Hint: Better feature selection, hierarchical classification, fine-tuned embeddings.
#
# 13. Your decision tree gives different predictions for the same input in different runs. Why?
# hashtag#Hint: No fixed random seed, tree instability, use ensemble methods.

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-8</div>

# %% [markdown]
# **Top Interview Questions for Data Science Freshers: ML, NLP, and Statistics** Part- 8
#
# hashtag#Machine_Learning_Questions_(Tricky but Basic)
# 1. Why do we prefer using cross-validation instead of a simple train-test split?
# 2. How does increasing the number of hidden layers in a neural network impact model performance?
# 3. Why is feature scaling important for algorithms like KNN and SVM but not for decision trees?
# 4. What is the difference between underfitting and overfitting? Can a model be both at the same time?
# 5. Why do we sometimes prefer simpler models (like logistic regression) over complex deep learning models?
# 6. How does the learning rate impact gradient descent, and what happens if it is too high or too low?
# 7. Why do deep learning models typically require large datasets to perform well?
# 8. What happens if you initialize all weights to zero in a neural network?
# 9. Why is dropout used in deep learning, and how does it help prevent overfitting?
# 10. How does batch normalization improve training stability in deep neural networks?
#
# hashtag#Natural_Language_Processing_(NLP)_Questions
# 1. If a chatbot keeps misinterpreting user queries, what are some potential causes?
# 2. How does an attention mechanism help in NLP models like transformers?
# 3. Why is one-hot encoding not a good choice for representing words in large vocabularies?
# 4. How does BERT differ from traditional word embedding techniques like Word2Vec?
# 5. Why is named entity recognition (NER) difficult in multilingual models?
# 6. Why might a TF-IDF vectorization approach fail in understanding sentence meaning?
#
# hashtag#Statistics_Probability_Questions
# 1. Why does correlation not imply causation? Give a real-world example.
# 2. If a dataset has extreme outliers, why might the median be a better measure of central tendency than the mean?
# 3. What is Simpson’s paradox, and how can it lead to incorrect conclusions?
# 4. Why is it important to check for multicollinearity in regression models?
# 5. What is heteroscedasticity, and why is it a problem in regression models?
#
# hashtag#Classification_Questions
# 1. Why is accuracy not always a good metric for evaluating classification models?
# 2. What is the difference between precision and recall, and when would you prioritize one over the other?
# 3. Why does increasing the number of training samples not always improve classification performance?
# 4. Why is softmax used instead of sigmoid in multi-class classification?
# 5. What happens if a logistic regression model is trained on highly correlated features?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-7</div>

# %% [markdown]
# **Top Interview Questions for Data Science Freshers: ML, NLP, and Statistics** Part-7
#
# Some of these are straightforward, but others are tricky and designed to test your understanding.
#
# **Machine Learning Questions**
# 1. Why is mean squared error (MSE) preferred over mean absolute error (MAE) in some cases, and vice versa?
# 2. If a model has 95% accuracy, does it mean it’s a good model? Why or why not?
# 3. Why do deep learning models perform better with large amounts of data but struggle with small datasets?
# 4. What happens if you remove all hidden layers from a neural network?
# 5. Can a model with high bias ever outperform a model with low bias?
#
# **Natural Language Processing (NLP) Questions**
# 1. Why might removing stopwords sometimes hurt model performance instead of improving it?
# 2. If two sentences have the same words but in a different order, will a bag-of-words model treat them as the same? Why or why not?
# 3. Why can’t we just use TF-IDF for deep learning-based NLP models?
# 4. How does a chatbot understand the intent behind a sentence?
# 5. Why is it difficult for AI models to understand sarcasm?
#
# **Statistics & Probability Questions**
# 1. If the probability of rain tomorrow is 80%, does that mean it will rain for 80% of the day? Why or why not?
# 2. Why can a small dataset sometimes give misleading statistical results?
# 3. If you flip a fair coin 10 times and get 7 heads, does that mean the coin is biased? Why or why not?
# 4. If a dataset has a mean of 50 and a median of 30, what does that suggest about its distribution?
# 5. Why is it incorrect to say that a p-value of 0.03 means there is a 97% probability the null hypothesis is false?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-6</div>

# %% [markdown]
# ⚜️Freshers Interview Questions for Machine Learning, NLP, Computer Vision, and Statistics⚜️ Part-6
#
# Here’s a new set of challenging yet insightful questions designed to help you sharpen your problem-solving and conceptual understanding across key areas of data science.
#
# **Machine Learning Questions**
# 1. Why might a model with high accuracy still fail to deliver business value?
# 2. How would you decide whether to use a bagging or boosting algorithm for a given dataset?
# 3. Why does PCA work better when features are standardized?
# 4. Why is feature selection important, and how does it impact interpretability in linear models?
# 5. Why might transfer learning not work well when applied to a significantly different domain?
#
# **Natural Language Processing Questions**
# 1. Why is contextual information critical for NLP tasks like machine translation or sentiment analysis?
# 2. How does cosine similarity differ from Euclidean distance when comparing text embeddings, and why is it often preferred?
# 3. Why does tokenization play a bigger role in languages like Chinese compared to English?
# 4. How does the concept of word sense disambiguation affect the performance of text-based models?
# 5. Why might a transformer-based model fail for very small datasets, and how could you address this?
#
# **Computer Vision Questions**
# 1. Why might a CNN trained on grayscale images not perform well on colored images, and how would you adapt it?
# 2. How does max-pooling help reduce computational complexity in convolutional networks?
# 3. Why is data augmentation more critical in computer vision compared to other fields?
# 4. How would you handle a multi-object detection task where objects frequently overlap?
# 5. Why might a GAN produce blurry images, and how could this issue be resolved?
#
# **Statistics Questions**
# 1. Why might a p-value be misleading when interpreting the significance of a result?
# 2. Why is heteroscedasticity a problem in linear regression, and how can it be addressed?
# 3. Why might confidence intervals be more informative than point estimates in real-world decision-making?
# 4. How does Bayesian inference differ from frequentist inference, and why might you prefer one over the other?
# 5. Why is it important to account for outliers in a dataset before performing statistical analyses?
#
# **Scenario-Based/Real-World Questions**
# 1. You’re working with a multi-class classification problem where one class is heavily underrepresented. How would you handle it?
# 2. Your NLP chatbot frequently misunderstands queries in dialects or slang. How would you improve it?
# 3. You’re training a computer vision model for defect detection, but the defects are rare. How would you handle the imbalance?
# 4. A stakeholder asks you to simplify a complex model for better interpretability. How would you approach the tradeoff between accuracy and simplicity?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-5</div>

# %% [markdown]
# ⚜️ Top Interview Questions for Data Science Freshers: ML, NLP, Statistics & Time Series ⚜️ - Part 5
#
# ⚜️Machine Learning Questions⚜️
# 1. Why might a simpler model like Ridge Regression outperform a more complex one like Gradient Boosting on certain datasets?
# 2. Why is the choice of distance metric critical in clustering algorithms, and how would you decide which one to use?
# 3. How would you explain the concept of cross-entropy loss to someone without a technical background?
# 4. Why do neural networks benefit from non-linear activation functions?
# 5. Why might feature interactions in linear models require manual engineering, but not in tree-based models?
#
# ⚜️Natural Language Processing Questions⚜️
# 1. How would you approach a text classification problem with a highly imbalanced dataset?
# 2. How does subword tokenization handle out-of-vocabulary (OOV) words better than traditional tokenization?
# 3. Why might text data with heavy sarcasm or negation pose challenges for sentiment analysis models?
# 4. Why does pre-training on large corpora make transformers so effective for NLP tasks?
#
# ⚜️Statistics Questions⚜️
# 1. Why is the standard deviation more useful than the range in describing the variability of a dataset?
# 2. Why might an unbiased estimator not always be preferred over a biased one?
# 3. How would you explain the importance of sampling distribution in inferential statistics?
# 4. Why might a statistically significant result not always be practically significant?
#
# ⚜️Time Series Questions⚜️
# 1. Why is stationarity important in time series forecasting, and how would you test for it?
# 2. How does differencing help in making a time series stationary, and why is it sometimes necessary?
# 3. Why might ARIMA models struggle with datasets that exhibit sudden structural changes or outliers?
# 4. How would you handle missing timestamps in a time-series dataset, and why might interpolation not always be the best choice?
# 5. Why is seasonality challenging in time-series forecasting, and how would you model it?
#
# ⚜️Scenario-Based/Real-World Questions⚜️
# 1. Your time-series model underperforms because the data has irregular intervals. How would you address this?
# 2. You’re building an image classification model, but the training data contains mislabeled samples. How would you identify and handle them?
# 3. Your NLP model fails to detect sarcasm in product reviews. How would you approach improving it?
# 4. A client asks you to predict energy demand for a smart grid. How would you handle exogenous variables like weather and holidays?
# 5. Your statistical analysis shows a significant relationship between variables, but the domain expert says it’s not meaningful. How would you reconcile this?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-4</div>

# %% [markdown]
# ⚜️ Top Interview Questions for Data Science Freshers: ML, NLP, and Statistics ⚜️ - Part 4
#
# 💡Machine Learning Questions
# 1. Why does adding noise to your data sometimes improve the robustness of a model?
# 2. Why might ensemble models like Random Forest perform poorly on a dataset with many categorical variables?
# 3. Why is the learning rate in gradient descent a critical hyperparameter, and how do you decide its value?
# 4. How would you explain the difference between bagging and boosting to a non-technical stakeholder?
# 5. Why does dropout improve generalization in neural networks, and how does it work?
#
# 💡Natural Language Processing Questions
# 1. Why might language models struggle with sarcasm or idioms, and how could you improve their performance in such cases?
# 2. Why are recurrent neural networks (RNNs) less efficient for handling long sequences compared to transformer models?
# 3. Why is the BLEU score commonly used for machine translation, and what are its limitations?
# 4. Why might stopword removal harm the performance of a topic modeling algorithm like LDA?
# 5. How would you approach cleaning noisy text data from multiple languages in a dataset?
#
# 💡 Statistics Questions
# 1. Why is it important to check for outliers before running statistical tests, and how might they impact results?
# 2. If two variables have a correlation coefficient of 0, why might they still have a relationship?
# 3. Why do Bayesian methods often require priors, and how do you select a good prior?
# 4. In regression, why might a high R-squared value still not indicate a good model?
# 5. Why is the assumption of independence important in many statistical tests, and how would you test for it?
#
# 💡 Scenario-Based/Real-World Questions
# 1. Your model’s predictions are consistently biased for one specific class. How would you debug and resolve this issue?
# 2. Why might scaling features improve performance in clustering algorithms like K-Means but not in tree-based models?
# 3. You’re asked to build a model for a rare disease prediction. Why might precision be more critical than recall in this case?
# 4. If a dataset has missing values in only one feature, why might imputing with the mean not always be a good idea?
# 5. Your team wants to deploy a sentiment analysis model, but the output is inconsistent. How would you identify and fix the issue?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-3</div>

# %% [markdown]
# **Top Interview Questions for Data Science Freshers: ML, NLP, and Statistics** - Part 3
#
#  **Machine Learning Questions**
# 1. Why might adding more features to a dataset degrade model performance? How would you identify and remove irrelevant features?
# 2. Why is gradient descent not guaranteed to find the global minimum in non-convex loss functions?
# 3. Why might you prefer a simpler model like Logistic Regression over a complex one like a Neural Network in some cases?
# 4. If your model's AUC score is high but precision is low, why might this happen, and how would you address it?
# 5. Why do tree-based algorithms like XGBoost handle missing values better than most other models?
#
#  **Natural Language Processing Questions**
# 1. Why is subword tokenization (e.g., Byte-Pair Encoding) useful in handling rare words in NLP tasks?
# 2. Why might overfitting be a bigger issue in NLP tasks compared to tabular data?
# 3. If you’re training an NLP model, why might smaller batch sizes lead to better generalization for text data?
# 4. Why do transformer models like GPT require positional encoding, and how does it work?
# 5. Why might text summarization models struggle with long documents, and how would you overcome this?
#
# **Statistics Questions**
# 1. Why is it important to check the distribution of residuals in regression analysis?
# 2. If two datasets have the same mean and variance, why might they still have very different distributions?
# 3. Why is it crucial to consider sample size when interpreting confidence intervals?
# 4. In A/B testing, why might a test that runs for too long lead to misleading results?
# 5. Why might you use bootstrapping instead of traditional hypothesis testing for small datasets?
#
# **Scenario-Based/Real-World Questions**
# 1. Your model is biased against certain demographics. Why might this happen, and how would you mitigate it?
# 2. You’re tasked with building a recommendation system for a new e-commerce site with no historical data. How would you approach this?
# 3. If your dataset contains a high percentage of duplicate entries, why might this affect your model’s performance?
# 4. Why might deploying a model trained on cloud GPUs fail to perform well on edge devices?
# 5. You’re working with a time-series dataset where sudden spikes occur. Why might traditional smoothing techniques fail, and what alternatives would you use?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-2</div>

# %% [markdown]
# **Top Interview Questions for Data Science Freshers: ML, NLP, and Statistics** - Part 2
#
#  **Machine Learning Questions**
# 1. Why does scaling features matter for algorithms like SVM or K-means, and when is it unnecessary?
# 2. In ensemble methods like Random Forest, why does increasing the number of trees sometimes stop improving accuracy?
# 3. Why might a model with high cross-validation accuracy still perform poorly on unseen test data?
# 4. Why is the R-squared metric not always a good indicator of model performance in regression?
# 5. If you have missing data, why might deleting rows or filling them with the mean not always be ideal?
#
#  **Natural Language Processing Questions**
# 1. Why do transformer-based models like BERT or GPT outperform traditional RNNs in NLP tasks?
# 2. How would you decide between using TF-IDF and Word2Vec for text vectorization?
# 3. Why might fine-tuning a pre-trained model like GPT yield better results than training from scratch?
# 4. If your NLP model generates irrelevant outputs, why might the temperature parameter be a factor?
# 5. Why is named entity recognition (NER) a challenging task, and how would you handle ambiguous entities?
#
# **Statistics Questions**
# 1. Why is the Central Limit Theorem important for data scientists working with small sample sizes?
# 2. How would you explain the difference between Type I and Type II errors, and why do both matter?
# 3. Why does multicollinearity affect regression models, and how can techniques like PCA help?
# 4. In hypothesis testing, why might a very small p-value still lead to incorrect conclusions?
# 5. Why is standard deviation preferred over variance when interpreting data spread?
#
# **Scenario-Based Questions**
# 1. If you’re working with a streaming dataset, why might batch processing not be suitable, and what alternatives would you consider?
# 2. Your model is performing well on training data but poorly on validation data. Why might regularization not always solve this?
# 3. A client insists on using deep learning for a small dataset. Why might this backfire, and how would you explain the risks?
# 4. Why might removing outliers improve a regression model’s performance but harm a classification model?
# 5. You have a perfectly balanced dataset but still experience poor classification accuracy. Why might the class separability be the issue?

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:25px;">Part-1</div>

# %% [markdown]
# **Top Interview Questions for Data Science Freshers: ML, NLP, and Statistics**
#
# Some of these are straightforward, but others are tricky and designed to test your understanding.
#
# **Machine Learning Questions**
# 1. Why do we split our dataset into training and testing sets, and how do you decide the right split ratio?
# 2. How does regularization prevent overfitting, and why do we use techniques like L1 and L2?
# 3. Why might a decision tree model overfit, and how can pruning help?
# 4. If you have a highly imbalanced dataset, why might accuracy not be the best metric? What would you use instead?
# 5. Why does the curse of dimensionality affect distance-based algorithms like KNN, and how can you address it?
#
# **Natural Language Processing Questions**
# 1. Why is tokenization an essential step in NLP, and what challenges arise when working with non-English languages?
# 2. Why do we use embeddings like Word2Vec or BERT instead of one-hot encoding for text data?
# 3. How would you handle out-of-vocabulary (OOV) words in a model?
# 4. Why is stemming or lemmatization important, and when would you avoid using them?
# 5. If you’re building a sentiment analysis model, why might stopwords still hold importance in some cases?
#
# **Statistics Questions**
# 1. Why is p-value important in hypothesis testing, and what does a p-value of 0.05 really mean?
# 2. If two variables have a high correlation, why doesn’t it always imply causation?
# 3. Why might the mean be misleading for a highly skewed dataset? What would you use instead?
# 4. Why do we prefer confidence intervals over point estimates in statistical analysis?
# 5. In linear regression, why is it important to check for multicollinearity?
#
# **Senior-Level/Tricky Questions**
# 1. Why might a gradient-boosting model outperform a deep learning model on small datasets?
# 2. If a dataset shows perfect multicollinearity between two features, why might one of them still be important?
# 3. When training a neural network for NLP, why might you freeze certain layers of the model?
# 4. Why might sampling strategies like SMOTE sometimes fail in addressing class imbalance?
# 5. Why does increasing the size of training data sometimes degrade performance on certain ML models?
